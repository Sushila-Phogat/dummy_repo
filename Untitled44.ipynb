# %% [markdown]
# <a href="https://colab.research.google.com/github/Sushila-Phogat/dummy_repo/blob/master/Untitled44.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Data

# %%
import pandas as pd
df=pd.read_excel('/content/Data_Scientist_Interview_Task.xlsx', sheet_name='Data')
print("Shape of Data: ", df.shape)
df.head(10)
# Out:
# Shape of Data:  (7691, 46)
#    Claim Number date_of_loss  ...      Incurred Capped Incurred
# 0             1   2003-04-15  ...      0.000000        0.000000
# 1             2   2003-04-20  ...   2801.308013     4074.670583
# 2             3   2003-04-24  ...   1220.870390     1775.829235
# 3             4   2003-05-13  ...   3529.868026     5134.404835
# 4             5   2003-06-11  ...   3155.987923     4590.573794
# 5             6   2003-06-24  ...  10502.083202    15275.910142
# 6             7   2003-07-16  ...     91.142730      132.572569
# 7             8   2003-07-17  ...   9129.967662    13280.085763
# 8             9   2003-07-20  ...     81.018992      117.846985
# 9            10   2003-07-29  ...    446.579011      649.575967
#
# [10 rows x 46 columns]

# %% [markdown]
# #Data Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7691 entries, 0 to 7690
# Data columns (total 46 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Claim Number                  7691 non-null   int64
#  1   date_of_loss                  7691 non-null   object
#  2   Notifier                      7691 non-null   object
#  3   Loss_code                     7691 non-null   object
#  4   Loss_description              7691 non-null   object
#  5   Notification_period           7691 non-null   int64
#  6   Inception_to_loss             7691 non-null   int64
#  7   Location_of_incident          7691 non-null   object
#  8   Weather_conditions            7346 non-null   object
#  9   Vehicle_mobile                7691 non-null   object
#  10  Time_hour                     7691 non-null   int64
#  11  Main_driver                   7691 non-null   object
#  12  PH_considered_TP_at_fault     7691 non-null   object
#  13  Vechile_registration_present  7691 non-null   int64
#  14  Incident_details_present      7691 non-null   int64
#  15  Injury_details_present        7691 non-null   int64
#  16  TP_type_insd_pass_back        7691 non-null   int64
#  17  TP_type_insd_pass_front       7691 non-null   int64
#  18  TP_type_driver                7691 non-null   int64
#  19  TP_type_pass_back             7691 non-null   int64
#  20  TP_type_pass_front            7691 non-null   int64
#  21  TP_type_bike                  7691 non-null   int64
#  22  TP_type_cyclist               7691 non-null   int64
#  23  TP_type_pass_multi            7691 non-null   int64
#  24  TP_type_pedestrian            7691 non-null   int64
#  25  TP_type_other                 7691 non-null   int64
#  26  TP_type_nk                    7691 non-null   int64
#  27  TP_injury_whiplash            7691 non-null   int64
#  28  TP_injury_traumatic           7691 non-null   int64
#  29  TP_injury_fatality            7691 non-null   int64
#  30  TP_injury_unclear             7691 non-null   int64
#  31  TP_injury_nk                  7691 non-null   int64
#  32  TP_region_eastang             7691 non-null   int64
#  33  TP_region_eastmid             7691 non-null   int64
#  34  TP_region_london              7691 non-null   int64
#  35  TP_region_north               7691 non-null   int64
#  36  TP_region_northw              7691 non-null   int64
#  37  TP_region_outerldn            7691 non-null   int64
#  38  TP_region_scotland            7691 non-null   int64
#  39  TP_region_southe              7691 non-null   int64
#  40  TP_region_southw              7691 non-null   int64
#  41  TP_region_wales               7691 non-null   int64
#  42  TP_region_westmid             7691 non-null   int64
#  43  TP_region_yorkshire           7691 non-null   int64
#  44  Incurred                      7691 non-null   float64
#  45  Capped Incurred               7691 non-null   float64
# dtypes: float64(2), int64(35), object(9)
# memory usage: 2.7+ MB

# %% [markdown]
# #Data Description

# %%
df.describe().T
# Out:
#                                count         mean  ...          75%           max
# Claim Number                  7691.0  3846.000000  ...  5768.500000  7.691000e+03
# Notification_period           7691.0     7.163438  ...     2.000000  1.042000e+03
# Inception_to_loss             7691.0   166.854505  ...   253.000000  3.650000e+02
# Time_hour                     7691.0    12.729684  ...    17.000000  2.300000e+01
# Vechile_registration_present  7691.0     0.999220  ...     1.000000  1.000000e+00
# Incident_details_present      7691.0     0.808347  ...     1.000000  1.000000e+00
# Injury_details_present        7691.0     0.232089  ...     0.000000  1.000000e+00
# TP_type_insd_pass_back        7691.0     0.028995  ...     0.000000  4.000000e+00
# TP_type_insd_pass_front       7691.0     0.000000  ...     0.000000  0.000000e+00
# TP_type_driver                7691.0     0.651671  ...     1.000000  5.000000e+00
# TP_type_pass_back             7691.0     0.041737  ...     0.000000  6.000000e+00
# TP_type_pass_front            7691.0     0.058380  ...     0.000000  2.000000e+00
# TP_type_bike                  7691.0     0.007281  ...     0.000000  2.000000e+00
# TP_type_cyclist               7691.0     0.000520  ...     0.000000  1.000000e+00
# TP_type_pass_multi            7691.0     0.000000  ...     0.000000  0.000000e+00
# TP_type_pedestrian            7691.0     0.000130  ...     0.000000  1.000000e+00
# TP_type_other                 7691.0     0.075023  ...     0.000000  6.000000e+00
# TP_type_nk                    7691.0     0.349369  ...     1.000000  6.000000e+00
# TP_injury_whiplash            7691.0     0.262515  ...     0.000000  7.000000e+00
# TP_injury_traumatic           7691.0     0.073072  ...     0.000000  4.000000e+00
# TP_injury_fatality            7691.0     0.003641  ...     0.000000  2.000000e+00
# TP_injury_unclear             7691.0     0.916136  ...     1.000000  7.000000e+00
# TP_injury_nk                  7691.0     0.595891  ...     1.000000  6.000000e+00
# TP_region_eastang             7691.0     0.039397  ...     0.000000  5.000000e+00
# TP_region_eastmid             7691.0     0.050969  ...     0.000000  6.000000e+00
# TP_region_london              7691.0     0.021584  ...     0.000000  9.000000e+00
# TP_region_north               7691.0     0.026915  ...     0.000000  4.000000e+00
# TP_region_northw              7691.0     0.066831  ...     0.000000  7.000000e+00
# TP_region_outerldn            7691.0     0.036406  ...     0.000000  5.000000e+00
# TP_region_scotland            7691.0     0.019893  ...     0.000000  6.000000e+00
# TP_region_southe              7691.0     0.115460  ...     0.000000  9.000000e+00
# TP_region_southw              7691.0     0.090235  ...     0.000000  5.000000e+00
# TP_region_wales               7691.0     0.056560  ...     0.000000  7.000000e+00
# TP_region_westmid             7691.0     0.073983  ...     0.000000  6.000000e+00
# TP_region_yorkshire           7691.0     0.079444  ...     0.000000  5.000000e+00
# Incurred                      7691.0  9423.264897  ...  6258.404402  1.951894e+06
# Capped Incurred               7691.0  8882.885505  ...  9103.224706  7.272800e+04
#
# [37 rows x 8 columns]

# %%
object_col=df.select_dtypes(exclude=['int64','float64']).columns
object_col
# Out:
# Index(['date_of_loss', 'Notifier', 'Loss_code', 'Loss_description',
#        'Location_of_incident', 'Weather_conditions', 'Vehicle_mobile',
#        'Main_driver', 'PH_considered_TP_at_fault'],
#       dtype='object')

# %%
numeric_col=df.select_dtypes(exclude=['object']).columns
numeric_col
# Out:
# Index(['Claim Number', 'Notification_period', 'Inception_to_loss', 'Time_hour',
#        'Vechile_registration_present', 'Incident_details_present',
#        'Injury_details_present', 'TP_type_insd_pass_back',
#        'TP_type_insd_pass_front', 'TP_type_driver', 'TP_type_pass_back',
#        'TP_type_pass_front', 'TP_type_bike', 'TP_type_cyclist',
#        'TP_type_pass_multi', 'TP_type_pedestrian', 'TP_type_other',
#        'TP_type_nk', 'TP_injury_whiplash', 'TP_injury_traumatic',
#        'TP_injury_fatality', 'TP_injury_unclear', 'TP_injury_nk',
#        'TP_region_eastang', 'TP_region_eastmid', 'TP_region_london',
#        'TP_region_north', 'TP_region_northw', 'TP_region_outerldn',
#        'TP_region_scotland', 'TP_region_southe', 'TP_region_southw',
#        'TP_region_wales', 'TP_region_westmid', 'TP_region_yorkshire',
#        'Incurred', 'Capped Incurred'],
#       dtype='object')

# %% [markdown]
# #Univariate Analysis

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(18,37))
for index,col in enumerate(numeric_col):
    plt.subplot(9,5,index+1)
    sns.distplot(df[col], kde=False)
fig.tight_layout(pad=1.0)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ####Claim number is constant distribution and having unique value for each row in whole data range. And Most of columns are having two type of data 0 or 1. A few column like notification_period, inception_to_loss, time_hour are having a flexible range.

# %% [markdown]
# #Boxplot for Each Numeric feature to check statistical characteristics

# %%
fig = plt.figure(figsize=(14,15))
for index,col in enumerate(numeric_col):
    plt.subplot(9,5,index+1)
    sns.boxplot(y=col, data=df)
fig.tight_layout(pad=1.0)

# %% [markdown]
# ####Upon seeing the box plot, no particular outlier highlighted for the features.

# %% [markdown]
# #Count plot for Categorical Features

# %%
fig = plt.figure(figsize=(15,25))
for index in range(len(object_col)):
    plt.subplot(9,5,index+1)
    sns.countplot(x=object_col[index], data=df)
    plt.xticks(rotation=90)
fig.tight_layout(pad=1.0)

# %% [markdown]
# #Bivariate Analysis

# %%
df.corr()
# Out:
#                               Claim Number  ...  Capped Incurred
# Claim Number                      1.000000  ...        -0.023388
# Notification_period               0.025530  ...        -0.019503
# Inception_to_loss                 0.028475  ...        -0.004767
# Time_hour                        -0.000915  ...         0.025716
# Vechile_registration_present      0.011457  ...         0.008974
# Incident_details_present          0.222212  ...         0.004430
# Injury_details_present           -0.021876  ...         0.154589
# TP_type_insd_pass_back            0.019044  ...         0.094924
# TP_type_insd_pass_front                NaN  ...              NaN
# TP_type_driver                    0.600639  ...         0.237739
# TP_type_pass_back                 0.029787  ...         0.300948
# TP_type_pass_front                0.027346  ...         0.400705
# TP_type_bike                      0.014106  ...         0.083645
# TP_type_cyclist                   0.015278  ...         0.000825
# TP_type_pass_multi                     NaN  ...              NaN
# TP_type_pedestrian                0.018578  ...         0.045270
# TP_type_other                    -0.082157  ...         0.281264
# TP_type_nk                       -0.628396  ...        -0.174397
# TP_injury_whiplash                0.041255  ...         0.517679
# TP_injury_traumatic               0.077086  ...         0.351515
# TP_injury_fatality                0.002063  ...         0.113937
# TP_injury_unclear                -0.085607  ...        -0.138388
# TP_injury_nk                      0.155294  ...        -0.073410
# TP_region_eastang                -0.031657  ...         0.104240
# TP_region_eastmid                -0.021484  ...         0.089410
# TP_region_london                  0.003510  ...         0.087093
# TP_region_north                  -0.010310  ...         0.079096
# TP_region_northw                 -0.015316  ...         0.190603
# TP_region_outerldn               -0.011342  ...         0.102142
# TP_region_scotland                0.005306  ...         0.119351
# TP_region_southe                 -0.070363  ...         0.127201
# TP_region_southw                 -0.084407  ...         0.067733
# TP_region_wales                  -0.019424  ...         0.122088
# TP_region_westmid                -0.003100  ...         0.177856
# TP_region_yorkshire              -0.022720  ...         0.192919
# Incurred                         -0.022306  ...         0.485905
# Capped Incurred                  -0.023388  ...         1.000000
#
# [37 rows x 37 columns]

# %%
plt.figure(figsize=(10,12))
correlation = df.corr()
sns.heatmap(correlation, mask = correlation <0.8, linewidth=0.5, cmap='BrBG_r')

# %% [markdown]
# ####There is no correlation between any two columns in the data

# %%
df.corr()[['Incurred']].sort_values(['Incurred'])
# Out:
#                               Incurred
# TP_type_nk                   -0.064356
# Claim Number                 -0.022306
# Incident_details_present     -0.002420
# TP_type_cyclist              -0.001335
# Notification_period           0.000417
# Vechile_registration_present  0.003849
# Inception_to_loss             0.005833
# Time_hour                     0.008816
# TP_type_pedestrian            0.013353
# TP_injury_unclear             0.018930
# TP_region_london              0.020618
# TP_region_outerldn            0.025699
# TP_injury_nk                  0.031540
# TP_region_southw              0.036932
# TP_region_scotland            0.041719
# TP_region_north               0.044479
# TP_region_wales               0.044515
# TP_region_northw              0.045868
# TP_type_bike                  0.056199
# TP_region_eastmid             0.060708
# TP_type_insd_pass_back        0.063193
# TP_region_westmid             0.063880
# TP_region_eastang             0.070791
# TP_region_yorkshire           0.081511
# TP_type_driver                0.091353
# Injury_details_present        0.094364
# TP_region_southe              0.104943
# TP_type_pass_back             0.113048
# TP_injury_whiplash            0.141303
# TP_type_pass_front            0.164683
# TP_injury_fatality            0.194936
# TP_type_other                 0.198345
# TP_injury_traumatic           0.252033
# Capped Incurred               0.485905
# Incurred                      1.000000
# TP_type_insd_pass_front            NaN
# TP_type_pass_multi                 NaN

# %% [markdown]
# #Data Preprocessing

# %% [markdown]
# ##Removing row with Special Character present in data

# %%
#Special character can be present only in the object type columns.
# And upon seeing the count plot for each object type column, we can see clearly that 
#only PH_considered_TP_at_fault column having '#' type special character.It is only one in count so droping row.
df=df.drop(df[df.PH_considered_TP_at_fault.str.contains(r'[@#&$%+*-]')].index)

# %% [markdown]
# ##Finding Redundant columns

# %%
df.nunique()
# Out:
# Claim Number                    7690
# date_of_loss                    3175
# Notifier                           5
# Loss_code                          1
# Loss_description                   1
# Notification_period              189
# Inception_to_loss                366
# Location_of_incident               8
# Weather_conditions                 4
# Vehicle_mobile                     3
# Time_hour                         24
# Main_driver                        3
# PH_considered_TP_at_fault          3
# Vechile_registration_present       2
# Incident_details_present           2
# Injury_details_present             2
# TP_type_insd_pass_back             5
# TP_type_insd_pass_front            1
# TP_type_driver                     6
# TP_type_pass_back                  7
# TP_type_pass_front                 3
# TP_type_bike                       3
# TP_type_cyclist                    2
# TP_type_pass_multi                 1
# TP_type_pedestrian                 2
# TP_type_other                      7
# TP_type_nk                         6
# TP_injury_whiplash                 8
# TP_injury_traumatic                5
# TP_injury_fatality                 3
# TP_injury_unclear                  8
# TP_injury_nk                       7
# TP_region_eastang                  6
# TP_region_eastmid                  7
# TP_region_london                   8
# TP_region_north                    5
# TP_region_northw                   8
# TP_region_outerldn                 6
# TP_region_scotland                 6
# TP_region_southe                   9
# TP_region_southw                   6
# TP_region_wales                    7
# TP_region_westmid                  7
# TP_region_yorkshire                6
# Incurred                        5718
# Capped Incurred                 5521
# dtype: int64

# %% [markdown]
# ####As Loss_code, Loss_description,TP_type_insd_pass_front,TP_type_pass_multi etc.  are having only one value for more than 96% which lead to no information addition. Droping all these columns will not impact data.

# %%
col = df.columns
overfit_col = []
for i in col:
    counts = df[i].value_counts()
    cnt = counts.iloc[0]
    
    if cnt / len(df) * 100 > 96:
        print(cnt,len(df))
        overfit_col.append(i)
overfit_col
# Out:
# 7690 7690
# 7690 7690
# 7684 7690
# 7530 7690
# 7690 7690
# 7463 7690
# 7636 7690
# 7686 7690
# 7690 7690
# 7689 7690
# 7664 7690
# 7445 7690
# 7566 7690
# 7527 7690
# 7456 7690
# 7572 7690
# ['Loss_code',
#  'Loss_description',
#  'Vechile_registration_present',
#  'TP_type_insd_pass_back',
#  'TP_type_insd_pass_front',
#  'TP_type_pass_back',
#  'TP_type_bike',
#  'TP_type_cyclist',
#  'TP_type_pass_multi',
#  'TP_type_pedestrian',
#  'TP_injury_fatality',
#  'TP_region_eastang',
#  'TP_region_london',
#  'TP_region_north',
#  'TP_region_outerldn',
#  'TP_region_scotland']

# %%
df=df.drop(overfit_col, axis=1)

# %%
#update numeric columns
numeric_col=df.select_dtypes(exclude=['object']).columns.to_list()
numeric_col
# Out:
# ['Claim Number',
#  'Notification_period',
#  'Inception_to_loss',
#  'Time_hour',
#  'Incident_details_present',
#  'Injury_details_present',
#  'TP_type_driver',
#  'TP_type_pass_front',
#  'TP_type_other',
#  'TP_type_nk',
#  'TP_injury_whiplash',
#  'TP_injury_traumatic',
#  'TP_injury_unclear',
#  'TP_injury_nk',
#  'TP_region_eastmid',
#  'TP_region_northw',
#  'TP_region_southe',
#  'TP_region_southw',
#  'TP_region_wales',
#  'TP_region_westmid',
#  'TP_region_yorkshire',
#  'Incurred',
#  'Capped Incurred']

# %% [markdown]
# ##Finding Null values in data frame

# %%
df.isnull().sum()
# Out:
# Claim Number                   0
# date_of_loss                   0
# Notifier                       0
# Notification_period            0
# Inception_to_loss              0
# Location_of_incident           0
# Weather_conditions           344
# Vehicle_mobile                 0
# Time_hour                      0
# Main_driver                    0
# PH_considered_TP_at_fault      0
# Incident_details_present       0
# Injury_details_present         0
# TP_type_driver                 0
# TP_type_pass_front             0
# TP_type_other                  0
# TP_type_nk                     0
# TP_injury_whiplash             0
# TP_injury_traumatic            0
# TP_injury_unclear              0
# TP_injury_nk                   0
# TP_region_eastmid              0
# TP_region_northw               0
# TP_region_southe               0
# TP_region_southw               0
# TP_region_wales                0
# TP_region_westmid              0
# TP_region_yorkshire            0
# Incurred                       0
# Capped Incurred                0
# dtype: int64

# %% [markdown]
# ##Treating the Missing values

# %%
df['Weather_conditions']=df.groupby('date_of_loss')['Weather_conditions'].fillna(df['Weather_conditions'].mode()[0])
df['Weather_conditions'].unique()
# Out:
# array(['NORMAL', 'WET', 'N/K', 'SNOW,ICE,FOG'], dtype=object)

# %% [markdown]
# ##Multicollinearity Check to remove redundant columns

# %%
plt.figure(figsize=(10,12))
correlation = df.corr()
sns.heatmap(correlation, mask = correlation <0.8, linewidth=0.5, cmap='BrBG_r')

# %% [markdown]
# #Feature Engineering

# %% [markdown]
# ##Date_of_loss is date field which is not giving particular info. So, instead of using it directly, we can take how old that loss is.

# %%
df['Age_of_loss']=(pd.datetime(2021, 7, 18)-pd.to_datetime(df['date_of_loss'])).dt.days
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   """Entry point for launching an IPython kernel.

# %%
df=df.drop('date_of_loss',axis=1)

# %% [markdown]
# ##Encoding

# %%
from sklearn.preprocessing import LabelEncoder
lbl_en=LabelEncoder()
for i in df.select_dtypes(exclude=['int64','float64']).columns:
  df[i]=lbl_en.fit_transform(df[i])

# %% [markdown]
# ##Scaling of Data

# %%
y=df[df.Incurred!=0].loc[:, df.columns == 'Incurred']
x=df[df.Incurred!=0].loc[:, df.columns != 'Incurred']

# %%
x_test2=df[df.Incurred==0].loc[:, df.columns != 'Incurred']
y_test2=df[df.Incurred==0].loc[:, df.columns == 'Incurred']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2020)

# %%
from sklearn.preprocessing import Normalizer
import numpy as np
scale=Normalizer()
X_train = scale.fit_transform(X_train)
X_test = scale.fit_transform(X_test)

# %% [markdown]
# #Modeling

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from xgboost import XGBRegressor
from sklearn import ensemble
from lightgbm import LGBMRegressor
from sklearn.model_selection import cross_val_score

# %%
from sklearn.model_selection import RandomizedSearchCV
xgb = XGBRegressor(booster='gbtree', objective='reg:squarederror')

param_lst = {
    'learning_rate' : [0.01, 0.1, 0.15, 0.3, 0.5],
    'n_estimators' : [100, 500, 1000, 2000, 3000],
    'max_depth' : [3, 6, 9],
    'min_child_weight' : [1, 5, 10, 20],
    'reg_alpha' : [0.001, 0.01, 0.1],
    'reg_lambda' : [0.001, 0.01, 0.1]
}

xgb_reg = RandomizedSearchCV(estimator = xgb, param_distributions = param_lst,
                              n_iter = 100, scoring = 'neg_root_mean_squared_error',
                              cv = 5)
       
xgb_search = xgb_reg.fit(X_train, y_train)

# XGB with tune hyperparameters
best_param = xgb_search.best_params_
xgb = XGBRegressor(**best_param)

# %%
lgbm = LGBMRegressor(boosting_type='gbdt',objective='regression', max_depth=-1,
                    lambda_l1=0.0001, lambda_l2=0, learning_rate=0.1,
                    n_estimators=100, max_bin=200, min_child_samples=20, 
                    bagging_fraction=0.75, bagging_freq=5,
                    bagging_seed=7, feature_fraction=0.8,
                    feature_fraction_seed=7, verbose=-1)

param_lst = {
    'max_depth' : [2, 5, 8, 10],
    'learning_rate' : [0.001, 0.01, 0.1, 0.2],
    'n_estimators' : [100, 300, 500, 1000, 1500],
    'lambda_l1' : [0.0001, 0.001, 0.01],
    'lambda_l2' : [0, 0.0001, 0.001, 0.01],
    'feature_fraction' : [0.4, 0.6, 0.8],
    'min_child_samples' : [5, 10, 20, 25]
}

lightgbm = RandomizedSearchCV(estimator = lgbm, param_distributions = param_lst,
                              n_iter = 100, scoring = 'neg_root_mean_squared_error',
                              cv = 5)
       
y = y_train.ravel()
y_train = np.array(y).astype(int)
lightgbm_search = lightgbm.fit(X_train, y_train)

# LightBGM with tuned hyperparameters
best_param = lightgbm_search.best_params_
lgbm = LGBMRegressor(**best_param)

# %%
model_performances = pd.DataFrame({
    "Model" : ["XGBoost", "LGBM"],
    "CV(5)" : [str(cv_xgb)[0:5], str(cv_lgbm)[0:5]],
    "MAE" : [str(mae_xgb)[0:5], str(mae_lgbm)[0:5]],
    "RMSE" : [str(rmse_xgb)[0:5], str(rmse_lgbm)[0:5]],
    "Score" : [str(score_xgb)[0:5], str(score_lgbm)[0:5]]
})

print("Sorted by Score:")
print(model_performances.sort_values(by="Score", ascending=False))
